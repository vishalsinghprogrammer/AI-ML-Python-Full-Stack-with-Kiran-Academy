# %%
import seaborn as sns
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

data =[25,35,25,15]
branches = ['karve','deccan','nagpur',' warje']
plt.pie(data,labels=branches,autopct='%1.1f%%',startangle=180,explode=[0.1,0.1,0.1,0.1])
plt.legend()

# %%
sns.scatterplot(data=student,)
